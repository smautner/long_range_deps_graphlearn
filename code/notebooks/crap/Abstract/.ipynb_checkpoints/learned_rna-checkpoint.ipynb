# %%
# %load_ext autoreload
# %autoreload 2
from eden.util import configure_logging
import logging
configure_logging(logging.getLogger(),verbosity=1)
# %matplotlib inline
# !pwd
# Out:
# /home/ikea/GraphLearn/GraphLearn_examples/Abstract

# %%
# get data
from itertools import islice
'''
Create a function that is able to deliver a graph iterator
'''
from eden.converter.fasta import fasta_to_sequence
from eden.converter.rna.rnafold import rnafold_to_eden

from eden.graph import Vectorizer
def rfam_uri(family_id):
    return 'http://rfam.xfam.org/family/%s/alignment?acc=%s&format=fastau&download=0'%(family_id,family_id)


def clean(graphs):
    for g in graphs:
        for n,d in g.nodes(data=True):
            if 'weight' in d:
                d.pop('weight')
        yield g


def rfam_uri(family_id):
    return '%s.fa'%(family_id)

def get_graphs(rfam_id = '../toolsdata/RF00005',size=9999):
    seqs = fasta_to_sequence(rfam_uri(rfam_id))
    graphs = islice( clean(rnafold_to_eden(seqs, shape_type=5, energy_range=30, max_num=3)), size)
    return graphs


from eden.converter.fasta import fasta_to_sequence
import itertools


def get_sequences(size=9999):
    sequences = itertools.islice( fasta_to_sequence("../toolsdata/RF00005.fa"), size)
    return [ b for (a,b) in sequences ]

def get_sequences_with_names(size=9999):
    sequences = itertools.islice( fasta_to_sequence("../toolsdata/RF00005.fa"), size)
    return sequences


#dataset_names = !cat NCI60/names
#dataset = dataset_names[4]
#dataset_fname = 'NCI60/' + dataset + '_orig_pos.gspan'
#print 'Working with dataset: %s' % dataset

# %%
'''DEBUGGING PREPROCESSA'''

from graphlearn.utils import draw
import graphlearn.abstract_graphs.learned_RNA as learned
from eden.graph import Vectorizer
if False:
    # if we are not interested in what the pp does we can skip this because it is slow
    # it shows how the created abstractions look like.
    v=Vectorizer(triangular_decomposition=False,complexity=3)
    pp=learned.RnaPreProcessor(kmeans_clusters=3,structure_mod=False)
    pp.set_param(v)
    gm=pp.fit_transform(get_sequences_with_names(40))

    for i in range(10):
        draw.graphlearn([gm[i+5].graph(),gm[i+5].base_graph(),gm[i+5].abstract_graph()],size=13,contract=True, abstract_color='red')

# %%
import eden.RNA
eden.RNA.Vectorizer()

# %%
# %%time
'''
learning a grammar
'''
import graphlearn.abstract_graphs.learned_RNA as learned
import graphlearn.abstract_graphs.RNA as rna
from graphlearn import feasibility
import graphlearn.estimator as estimator
graphs = get_sequences_with_names(200)

estimator=estimator.Wrapper( nu=.33, cv=2, n_jobs=-1)
feas=feasibility.FeasibilityChecker(checklist=[feasibility.default_check,rna.is_rna])

pp=learned.RnaPreProcessor(base_thickness_list=[2],kmeans_clusters=3,structure_mod=False)
sampler=rna.AbstractSampler(radius_list=[0,1],
                            thickness_list=[1], 
                            min_cip_count=1, 
                            min_interface_count=2,
                            feasibility_checker=feas, 
                            preprocessor=pp,
                            estimator=estimator)
sampler.fit(graphs,grammar_n_jobs=4,grammar_batch_size=1)
sampler.save('../tmp/rna_annotate.ge')
# Out:
# Warning: fit was asked with n=1
#
# Classifier:
# SGDClassifier(alpha=0.000763378488945, average=False, class_weight=None,
#        epsilon=0.1, eta0=0.573440549657, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='constant', loss='log', n_iter=47, n_jobs=1,
#        penalty='l2', power_t=0.61191404511, random_state=None,
#        shuffle=True, verbose=0, warm_start=False)
#
# Predictive performance:
#             accuracy: 1.000 +- 0.000
#            precision: 1.000 +- 0.000
#               recall: 1.000 +- 0.000
#                   f1: 1.000 +- 0.000
#    average_precision: 1.000 +- 0.000
#              roc_auc: 1.000 +- 0.000
# fit pp done
# Warning: fit was asked with n=1
#
# Classifier:
# SGDClassifier(alpha=0.000738124280885, average=False, class_weight=None,
#        epsilon=0.1, eta0=0.824845998813, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=44, n_jobs=1,
#        penalty='elasticnet', power_t=0.992026145308, random_state=None,
#        shuffle=True, verbose=0, warm_start=False)
#
# Predictive performance:
#             accuracy: 1.000 +- 0.000
#            precision: 1.000 +- 0.000
#               recall: 1.000 +- 0.000
#                   f1: 1.000 +- 0.000
#    average_precision: 1.000 +- 0.000
#              roc_auc: 1.000 +- 0.000
# #instances: 200  #interfaces: 783   #cores: 875   #core-interface-pairs: 2210
# Saved model: ../tmp/rna_annotate.ge
# CPU times: user 2min 20s, sys: 32.6 s, total: 2min 52s
# Wall time: 5min 47s

# %%
#draw production rules
draw.draw_grammar(sampler.lsgg.productions,n_productions=5,n_graphs_per_production=5,
                     n_graphs_per_line=5, size=9, contract=False,
                     colormap='Paired', invert_colormap=False,node_border=1,
                     vertex_alpha=0.6, edge_alpha=0.5, node_size=450, abstract_interface=True)
# Out:
# interface id: 826720 [14 options]
# interface id: 429552 [13 options]
# interface id: 910766 [11 options]
# interface id: 257368 [11 options]
# interface id: 74736 [10 options]

# %%
# %%time

import os
os.nice(19)
import graphlearn.utils.draw as draw
import itertools

graphs = get_sequences()

id_start=66
id_end=id_start+12
graphs = itertools.islice(graphs,id_start,id_end)
n_steps=100

graphs = sampler.sample(graphs,
                        n_samples=4,
                        batch_size=1,
                        n_steps=n_steps,
                        n_jobs=2,
                        quick_skip_orig_cip=True,
                        probabilistic_core_choice=True,
                        burnin=0,
                        improving_threshold=0.9,
                        improving_linear_start=0.1,
                        max_size_diff=20,
                        select_cip_max_tries=40,
                        keep_duplicates=False,
                        accept_min_similarity=0.55,
                        include_seed=True,
                        backtrack=10,
                        monitor=True)


scores=[]
sequences=[]
ids=range(id_start,id_end)
for i,graph in enumerate(graphs):
    print 'Graph id: %d'%(ids[i])
    scores.append(sampler.monitors[i].sampling_info['score_history'])
    path_graphs = graph
    sequences.append(sampler.monitors[i].sampling_info['notes'])    

    path_graphs= list(path_graphs)
    draw.graphlearn(path_graphs,
                           n_graphs_per_line=5, size=10, 
                           colormap='Paired', invert_colormap=False,node_border=0.5, vertex_color='color_level',
                           vertex_alpha=0.5, edge_alpha=0.7, node_size=450,edge_label='label'
                          
                          )
# Out:
# preprocessing grammar
# _propose_graph: iteration 0 ; core 0 of 1 ; original_cips tried  0 ; size 168
# _propose_graph: iteration 61 ; core 0 of 4 ; original_cips tried  0 ; size 176
# _propose_graph: iteration 1 ; core 0 of 1 ; original_cips tried  0 ; size 166
# _propose_graph: iteration 62 ; core 0 of 12 ; original_cips tried  0 ; size 176
# _propose_graph: iteration 2 ; core 0 of 4 ; original_cips tried  0 ; size 166
# _propose_graph: iteration 63 ; core 0 of 12 ; original_cips tried  0 ; size 176
# _propose_graph: iteration 3 ; core 0 of 2 ; original_cips tried  0 ; size 166
# _propose_graph: iteration 64 ; core 0 of 12 ; original_cips tried  0 ; size 176
# _propose_graph: iteration
; core 0 of 2 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 8 ; core 0 of 3 ; original_cips tried  0 ; size 207
# _propose_graph: iteration 48 ; core 0 of 1 ; original_cips tried  1 ; size 186
# _propose_graph: iteration 9 ; core 0 of 6 ; original_cips tried  0 ; size 207
# _propose_graph: iteration 49 ; core 0 of 1 ; original_cips tried  0 ; size 186
# _propose_graph: iteration 10 ; core 0 of 1 ; original_cips tried  0 ; size 203
# _propose_graph: iteration 50 ; core 0 of 6 ; original_cips tried  1 ; size 180
# _propose_graph: iteration 11 ; core 0 of 1 ; original_cips tried  0 ; size 203
# _propose_graph: iteration 51 ; core 0 of 2 ; original_cips tried  0 ; size 174
# _propose_graph: iteration 12 ; core 0 of 5 ; original_cips tried  0 ; size 197
# _propose_graph: iteration 52 ; core 0 of 12 ; original_cips tried  2 ; size 166
# _propose_graph: iteration 13 ; core 0 of 1 ; original_cips tried  0 ; size 195
# _propose_graph: iteration 53 ; core 0 of 3 ; original_cips tried  2 ; size 166
# _propose_graph: iteration 14 ; core 0 of 1 ; original_cips tried  1 ; size 199
# _propose_graph: iteration 54 ; core 0 of 4 ; original_cips tried  0 ; size 170
# _propose_graph: iteration 15 ; core 0 of 2 ; original_cips tried  0 ; size 205
# _propose_graph: iteration 55 ; core 0 of 4 ; original_cips tried  0 ; size 170
# faster iso check failed
# _propose_graph: iteration 56 ; core 0 of 6 ; original_cips tried  1 ; size 170
# _propose_graph: iteration 16 ; core 0 of 2 ; original_cips tried  1 ; size 205
# _propose_graph: iteration 57 ; core 0 of 4 ; original_cips tried  0 ; size 170
# _propose_graph: iteration 17 ; core 0 of 1 ; original_cips tried  0 ; size 205
# _propose_graph: iteration 58 ; core 0 of 12 ; original_cips tried  1 ; size 170
# _propose_graph: iteration 18 ; core 0 of 1 ; original_cips tried  1 ; size 193
# _propose_graph: iteration 59 ; core 0 of 1 ; original_cips tried  1 ; size 170
# _propose_graph: iteration 19 ; core 0 of 2 ; original_cips tried  0 ; size 193
# _propose_graph: iteration 60 ; core 0 of 3 ; original_cips tried  0 ; size 168
# _propose_graph: iteration 20 ; core 0 of 2 ; original_cips tried  0 ; size 179
# _propose_graph: iteration 61 ; core 0 of 3 ; original_cips tried  0 ; size 170
# _propose_graph: iteration 21 ; core 0 of 6 ; original_cips tried  0 ; size 179
# _sample_notes: None
# accept_min_similarity: 0.55
# accept_static_penalty: 0.0
# batch_size: 1
#     burnin: 0
# estimatorobject: <graphlearn.estimator.Wrapper instance at 0x7fdf23bc2ab8>
# feasibility_checker: <graphlearn.feasibility.FeasibilityChecker instance at 0x7fdf23bc29e0>
# hash_bitmask: 1048575
# improving_linear_start: 10
# improving_penalty_per_step: 0.0125
# improving_threshold: 90
# include_seed: True
# keep_duplicates: False
#       lsgg: <graphlearn.localsubstitutablegraphgrammar.LocalSubstitutableGraphGrammar object at 0x7fdf239f8990>
# max_core_size_diff: 40
# maxbacktrack: 10
#    monitor: True
#   monitors: []
#     n_jobs: 2
#    n_steps: 100
#       nbit: 20
# node_entity_check: <function <lambda> at 0x7fdf23b8a9b0>
# postprocessor: <graphlearn.processing.PostProcessor object at 0x7fdf23b8c250>
# preprocessor: <graphlearn.abstract_graphs.learned_RNA.RnaPreProcessor object at 0x7fdf239f8910>
# probabilistic_core_choice: True
# proposal_probability: False
# quick_skip_orig_cip: True
# radius_list: [0, 2]
# random_state: None
# sample_path: None
# sampling_interval: 25
# score_core_choice: False
# select_cip_max_tries: 40
# similarity: -1
#       step: None
# target_orig_cip: False
# thickness_list: [2]
# vectorizer: graph.Vectorizer( r = 3, d = 3, n = 1, min_r = 0, min_d = 0, min_n = 2,                          label_size = 1, nbits = 20, status = None, normalization = True,                          inner_normalization = True, triangular_decomposition = False )
# _propose_graph: iteration 62 ; core 0 of 4 ; original_cips tried  0 ; size 166
# _propose_graph: iteration 22 ; core 0 of 6 ; original_cips tried  0 ; size 178
# _propose_graph: iteration 63 ; core 0 of 4 ; original_cips tried  0 ; size 166
# _propose_graph: iteration 23 ; core 0 of 4 ; original_cips tried  0 ; size 178
# _propose_graph: iteration 64 ; core 0 of 1 ; original_cips tried  1 ; size 172
# faster iso check failed
# _propose_graph: iteration 65 ; core 0 of 4 ; original_cips tried  0 ; size 176
# _propose_graph: iteration 24 ; core 0 of 1 ; original_cips tried  1 ; size 179
# _propose_graph: iteration 66 ; core 0 of 6 ; original_cips tried  0 ; size 176
# _propose_graph: iteration 25 ; core 0 of 1 ; original_cips tried  0 ; size 173
# _propose_graph: iteration 67 ; core 0 of 9 ; original_cips tried  0 ; size 176
# _propose_graph: iteration 26 ; core 0 of 6 ; original_cips tried  1 ; size 169
# _propose_graph: iteration 68 ; core 0 of 4 ; original_cips tried  0 ; size 176
# _propose_graph: iteration 27 ; core 0 of 1 ; original_cips tried  2 ; size 173
# _propose_graph: iteration 69 ; core 0 of 9 ; original_cips tried  0 ; size 176
# _propose_graph: iteration 28 ; core 0 of 1 ; original_cips tried  0 ; size 173
# _propose_graph: iteration 70 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 29 ; core 0 of 1 ; original_cips tried  0 ; size 173
# _propose_graph: iteration 71 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 30 ; core 0 of 1 ; original_cips tried  0 ; size 173
# _propose_graph: iteration 72 ; core 0 of 3 ; original_cips tried  0 ; size 178
# _propose_graph: iteration 31 ; core 0 of 2 ; original_cips tried  2 ; size 173
# _propose_graph: iteration 73 ; core 0 of 3 ; original_cips tried  0 ; size 178
# _propose_graph: iteration 32 ; core 0 of 2 ; original_cips tried  0 ; size 172
# _propose_graph: iteration 74 ; core 0 of 5 ; original_cips tried  1 ; size 178
# _propose_graph: iteration 33 ; core 0 of 1 ; original_cips tried  0 ; size 165
# _propose_graph: iteration 75 ; core 0 of 1 ; original_cips tried  0 ; size 178
# _propose_graph: iteration 34 ; core 0 of 1 ; original_cips tried  1 ; size 165
# _propose_graph: iteration 76 ; core 0 of 2 ; original_cips tried  0 ; size 172
# _propose_graph: iteration 35 ; core 0 of 1 ; original_cips tried  0 ; size 165
# _propose_graph: iteration 77 ; core 0 of 1 ; original_cips tried  0 ; size 172
# _propose_graph: iteration 36 ; core 0 of 1 ; original_cips tried  0 ; size 160
# _propose_graph: iteration 78 ; core 0 of 2 ; original_cips tried  1 ; size 172
# _propose_graph: iteration 37 ; core 0 of 1 ; original_cips tried  0 ; size 160
# _propose_graph: iteration 79 ; core 0 of 3 ; original_cips tried  0 ; size 172
# _propose_graph: iteration 38 ; core 0 of 1 ; original_cips tried  0 ; size 159
# _propose_graph: iteration 80 ; core 0 of 2 ; original_cips tried  0 ; size 172
# _propose_graph: iteration 39 ; core 0 of 3 ; original_cips tried  0 ; size 159
# _propose_graph: iteration 81 ; core 0 of 6 ; original_cips tried  0 ; size 172
# select_cip_for_substitution failed because no suiting interface was found,             extract failed 40 times; cip found but unacceptable:40
# _propose_graph: iteration 82 ; core 0 of 4 ; original_cips tried  0 ; size 168
# select_cip_for_substitution failed because no suiting interface was found,             extract failed 40 times; cip found but unacceptable:40
# _propose_graph: iteration 83 ; core 0 of 6 ; original_cips tried  0 ; size 168
# propose failed.. usualy the problem is propose_single_cip
# _propose_graph: iteration 84 ; core 0 of 3 ; original_cips tried  1 ; size 168
# Traceback (most recent call last):
#   File "/home/ikea/GraphLearn/graphlearn/graphlearn.py", line 407, in _sample
#     candidate_graph_manager = self._propose(graph_manager)
#   File "/home/ikea/GraphLearn/graphlearn/graphlearn.py", line 618, in _propose
#     raise Exception("propose failed.. usualy the problem is propose_single_cip")
# Exception: propose failed.. usualy the problem is propose_single_cip
#
# _propose_graph: iteration 85 ; core 0 of 3 ; original_cips tried  0 ; size 168
# _sample stopped at 39 out of 100 n_steps
# _propose_graph: iteration 86 ; core 0 of 4 ; original_cips tried  0 ; size 168
# _propose_graph: iteration 0 ; core 0 of 1 ; original_cips tried  0 ; size 167
# _propose_graph: iteration 87 ; core 0 of 6 ; original_cips tried  1 ; size 168
# _propose_graph: iteration 1 ; core 0 of 2 ; original_cips tried  0 ; size
; original_cips tried  0 ; size 184
# _propose_graph: iteration 37 ; core 0 of 2 ; original_cips tried  0 ; size 169
# _propose_graph: iteration 24 ; core 0 of 3 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 38 ; core 0 of 2 ; original_cips tried  0 ; size 166
# _propose_graph: iteration 25 ; core 0 of 2 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 39 ; core 0 of 1 ; original_cips tried  0 ; size 177
# _propose_graph: iteration 26 ; core 0 of 6 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 40 ; core 0 of 7 ; original_cips tried  0 ; size 177
# _propose_graph: iteration 27 ; core 0 of 1 ; original_cips tried  0 ; size 188
# _propose_graph: iteration 41 ; core 0 of 7 ; original_cips tried  0 ; size 177
# _propose_graph: iteration 28 ; core 0 of 1 ; original_cips tried  0 ; size 188
# _propose_graph: iteration 42 ; core 0 of 1 ; original_cips tried  0 ; size 175
# _propose_graph: iteration 29 ; core 0 of 2 ; original_cips tried  0 ; size 188
# _propose_graph: iteration 43 ; core 0 of 2 ; original_cips tried  0 ; size 177
# _propose_graph: iteration 30 ; core 0 of 3 ; original_cips tried  0 ; size 188
# _propose_graph: iteration 44 ; core 0 of 2 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 31 ; core 0 of 1 ; original_cips tried  0 ; size 188
# select_cip_for_substitution failed because no suiting interface was found,             extract failed 38 times; cip found but unacceptable:38
# _propose_graph: iteration 32 ; core 0 of 4 ; original_cips tried  0 ; size 190
# _propose_graph: iteration 44 ; core 0 of 2 ; original_cips tried  1 ; size 183
# _propose_graph: iteration 33 ; core 0 of 1 ; original_cips tried  1 ; size 190
# _propose_graph: iteration 45 ; core 0 of 4 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 34 ; core 0 of 1 ; original_cips tried  0 ; size 190
# _propose_graph: iteration 46 ; core 0 of 2 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 35 ; core 0 of 2 ; original_cips tried  0 ; size 190
# _propose_graph: iteration 47 ; core 0 of 3 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 36 ; core 0 of 1 ; original_cips tried  0 ; size 197
# _propose_graph: iteration 48 ; core 0 of 1 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 37 ; core 0 of 1 ; original_cips tried  0 ; size 198
# _propose_graph: iteration 49 ; core 0 of 2 ; original_cips tried  2 ; size 183
# _propose_graph: iteration 38 ; core 0 of 3 ; original_cips tried  0 ; size 195
# _propose_graph: iteration 50 ; core 0 of 1 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 39 ; core 0 of 1 ; original_cips tried  0 ; size 192
# _propose_graph: iteration 51 ; core 0 of 2 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 40 ; core 0 of 1 ; original_cips tried  0 ; size 198
# _propose_graph: iteration 52 ; core 0 of 2 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 41 ; core 0 of 1 ; original_cips tried  0 ; size 198
# _propose_graph: iteration 53 ; core 0 of 1 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 42 ; core 0 of 1 ; original_cips tried  0 ; size 200
# _propose_graph: iteration 54 ; core 0 of 2 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 43 ; core 0 of 1 ; original_cips tried  1 ; size 196
# _propose_graph: iteration 55 ; core 0 of 2 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 44 ; core 0 of 3 ; original_cips tried  0 ; size 196
# select_cip_for_substitution failed because no suiting interface was found,             extract failed 39 times; cip found but unacceptable:39
# _propose_graph: iteration 45 ; core 0 of 2 ; original_cips tried  0 ; size 194
# _propose_graph: iteration 55 ; core 0 of 2 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 46 ; core 0 of 1 ; original_cips tried  0 ; size 189
# _propose_graph: iteration 56 ; core 0 of 2 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 47 ; core 0 of 2 ; original_cips tried  0 ; size 189
# _propose_graph: iteration 57 ; core 0 of 1 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 48 ; core 0 of 6 ; original_cips tried  0 ; size 189
# _propose_graph: iteration 58 ; core 0 of 3 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 49 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 59 ; core 0 of 4 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 50 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 60 ; core 0 of 3 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 51 ; core 0 of 2 ; original_cips tried  0 ; size 180
# select_cip_for_substitution failed because no suiting interface was found,             extract failed 40 times; cip found but unacceptable:40
# _propose_graph: iteration 52 ; core 0 of 1 ; original_cips tried  1 ; size 180
# _propose_graph: iteration 60 ; core 0 of 3 ; original_cips tried  0 ; size 183
# _propose_graph: iteration 53 ; core 0 of 2 ; original_cips tried  1 ; size 180
# _propose_graph: iteration 61 ; core 0 of 1 ; original_cips tried  0 ; size 181
# _propose_graph: iteration 54 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 62 ; core 0 of 1 ; original_cips tried  0 ; size 181
# _propose_graph: iteration 55 ; core 0 of 5 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 63 ; core 0 of 2 ; original_cips tried  0 ; size 181
# _propose_graph: iteration 56 ; core 0 of 1 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 64 ; core 0 of 1 ; original_cips tried  0 ; size 181
# _propose_graph: iteration 57 ; core 0 of 1 ; original_cips tried  0 ; size 182
# select_cip_for_substitution failed because no suiting interface was found,             extract failed 39 times; cip found but unacceptable:39
# _propose_graph: iteration 58 ; core 0 of 8 ; original_cips tried  0 ; size 180
# select_cip_for_substitution failed because no suiting interface was found,             extract failed 40 times; cip found but unacceptable:40
# _propose_graph: iteration 59 ; core 0 of 1 ; original_cips tried  0 ; size 180
# propose failed.. usualy the problem is propose_single_cip
# _propose_graph: iteration 60 ; core 0 of 2 ; original_cips tried  0 ; size 180
# Traceback (most recent call last):
#   File "/home/ikea/GraphLearn/graphlearn/graphlearn.py", line 407, in _sample
#     candidate_graph_manager = self._propose(graph_manager)
#   File "/home/ikea/GraphLearn/graphlearn/graphlearn.py", line 618, in _propose
#     raise Exception("propose failed.. usualy the problem is propose_single_cip")
# Exception: propose failed.. usualy the problem is propose_single_cip
#
# _propose_graph: iteration 61 ; core 0 of 3 ; original_cips tried  0 ; size 180
# _sample stopped at 64 out of 100 n_steps
# _propose_graph: iteration 62 ; core 0 of 2 ; original_cips tried  0 ; size 180
# faster iso check failed
# _propose_graph: iteration 63 ; core 0 of 1 ; original_cips tried  1 ; size 180
# _propose_graph: iteration 0 ; core 0 of 1 ; original_cips tried  1 ; size 165
# _propose_graph: iteration 64 ; core 0 of 1 ; original_cips tried  1 ; size 182
# _propose_graph: iteration 1 ; core 0 of 2 ; original_cips tried  0 ; size 167
# _propose_graph: iteration 65 ; core 0 of 2 ; original_cips tried  1 ; size 182
# faster iso check failed
# _propose_graph: iteration 66 ; core 0 of 2 ; original_cips tried  1 ; size 182
# _propose_graph: iteration 2 ; core 0 of 6 ; original_cips tried  1 ; size 167
# _propose_graph: iteration 67 ; core 0 of 1 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 3 ; core 0 of 2 ; original_cips tried  0 ; size 167
# _propose_graph: iteration 68 ; core 0 of 5 ; original_cips tried  0 ; size 182
# faster iso check failed
# _propose_graph: iteration 69 ; core 0 of 2 ; original_cips tried  1 ; size 182
# _propose_graph: iteration 4 ; core 0 of 1 ; original_cips tried  2 ; size 163
# _propose_graph: iteration 70 ; core 0 of 1 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 5 ; core 0 of 1 ; original_cips tried  0 ; size 158
# _propose_graph: iteration 71 ; core 0 of 12 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 6 ; core 0 of 1 ; original_cips tried  1 ; size 157
# _propose_graph: iteration 72 ; core 0 of 1 ; original_cips tried  0 ; size 182
# faster iso check failed
# _propose_graph: iteration 73 ; core 0 of 2 ; original_cips tried  2 ; size 182
# _propose_graph: iteration 7 ; core 0 of 6 ; original_cips tried  2 ; size 157
# _propose_graph: iteration 74 ; core 0 of 1 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 8 ; core 0 of 1 ; original_cips tried  1 ; size 159
# _propose_graph: iteration 75 ; core 0 of 2 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 9 ; core 0 of 2 ; original_cips tried  0 ; size 159
# _propose_graph: iteration 76 ; core 0 of 2 ; original_cips tried  1 ; size 180
# _propose_graph: iteration 10 ; core 0 of 1 ; original_cips tried  0 ; size 153
# _propose_graph: iteration 77 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 11 ; core 0 of 1 ; original_cips tried  0 ; size 153
# _propose_graph: iteration 78 ; core 0 of 1 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 12 ; core 0 of 1 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 79 ; core 0 of 6 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 13 ; core 0 of 1 ; original_cips tried  0 ; size 153
# _propose_graph: iteration 80 ; core 0 of 3 ; original_cips tried  1 ; size 182
# _propose_graph: iteration 14 ; core 0 of 1 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 81 ; core 0 of 1 ; original_cips tried  0 ; size 182
# _propose_graph: iteration 15 ; core 0 of 2 ; original_cips tried  2 ; size 149
# _propose_graph: iteration 82 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 16 ; core 0 of 1 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 83 ; core 0 of 2 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 17 ; core 0 of 1 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 84 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 18 ; core 0 of 2 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 85 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 19 ; core 0 of 2 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 86 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 20 ; core 0 of 2 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 87 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 21 ; core 0 of 1 ; original_cips tried  1 ; size 149
# _propose_graph: iteration 88 ; core 0 of 2 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 22 ; core 0 of 12 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 89 ; core 0 of 2 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 23 ; core 0 of 2 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 90 ; core 0 of 2 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 24 ; core 0 of 1 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 91 ; core 0 of 12 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 25 ; core 0 of 1 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 92 ; core 0 of 2 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 26 ; core 0 of 5 ; original_cips tried  1 ; size 149
# _propose_graph: iteration 93 ; core 0 of 12 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 27 ; core 0 of 12 ; original_cips tried  0 ; size 147
# _propose_graph: iteration 94 ; core 0 of 2 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 28 ; core 0 of 12 ; original_cips tried  0 ; size 147
# _propose_graph: iteration 95 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 29 ; core 0 of 12 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 96 ; core 0 of 1 ; original_cips tried  1 ; size 180
# _propose_graph: iteration 30 ; core 0 of 2 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 97 ; core 0 of 1 ; original_cips tried  0 ; size 180
# _propose_graph: iteration 31 ; core 0 of 2 ; original_cips tried  0 ; size 149
# _propose_graph: iteration
; original_cips tried  0 ; size 196
# _propose_graph: iteration 67 ; core 0 of 1 ; original_cips tried  0 ; size 157
# _propose_graph: iteration 34 ; core 0 of 1 ; original_cips tried  0 ; size 196
# _propose_graph: iteration 68 ; core 0 of 1 ; original_cips tried  0 ; size 157
# _propose_graph: iteration 35 ; core 0 of 4 ; original_cips tried  0 ; size 205
# _propose_graph: iteration 69 ; core 0 of 1 ; original_cips tried  0 ; size 159
# _propose_graph: iteration 36 ; core 0 of 1 ; original_cips tried  0 ; size 205
# _propose_graph: iteration 70 ; core 0 of 12 ; original_cips tried  0 ; size 159
# _propose_graph: iteration 37 ; core 0 of 1 ; original_cips tried  0 ; size 205
# _propose_graph: iteration 71 ; core 0 of 3 ; original_cips tried  1 ; size 151
# _propose_graph: iteration 38 ; core 0 of 1 ; original_cips tried  0 ; size 206
# _propose_graph: iteration 72 ; core 0 of 1 ; original_cips tried  1 ; size 151
# _propose_graph: iteration 39 ; core 0 of 2 ; original_cips tried  0 ; size 204
# _propose_graph: iteration 73 ; core 0 of 6 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 40 ; core 0 of 13 ; original_cips tried  0 ; size 199
# _propose_graph: iteration 74 ; core 0 of 12 ; original_cips tried  1 ; size 151
# _propose_graph: iteration 41 ; core 0 of 3 ; original_cips tried  1 ; size 203
# _propose_graph: iteration 75 ; core 0 of 5 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 42 ; core 0 of 1 ; original_cips tried  0 ; size 210
# _propose_graph: iteration 76 ; core 0 of 2 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 43 ; core 0 of 2 ; original_cips tried  0 ; size 206
# _propose_graph: iteration 77 ; core 0 of 1 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 44 ; core 0 of 1 ; original_cips tried  0 ; size 206
# _propose_graph: iteration 78 ; core 0 of 2 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 45 ; core 0 of 1 ; original_cips tried  0 ; size 206
# _propose_graph: iteration 79 ; core 0 of 6 ; original_cips tried  1 ; size 151
# _propose_graph: iteration 46 ; core 0 of 6 ; original_cips tried  0 ; size 206
# _propose_graph: iteration 80 ; core 0 of 3 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 47 ; core 0 of 1 ; original_cips tried  2 ; size 194
# _propose_graph: iteration 81 ; core 0 of 1 ; original_cips tried  1 ; size 149
# _propose_graph: iteration 48 ; core 0 of 1 ; original_cips tried  0 ; size 194
# _propose_graph: iteration 82 ; core 0 of 12 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 49 ; core 0 of 3 ; original_cips tried  0 ; size 202
# _propose_graph: iteration 83 ; core 0 of 3 ; original_cips tried  0 ; size 149
# _propose_graph: iteration 50 ; core 0 of 1 ; original_cips tried  1 ; size 202
# _propose_graph: iteration 84 ; core 0 of 3 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 51 ; core 0 of 1 ; original_cips tried  0 ; size 202
# _propose_graph: iteration 85 ; core 0 of 12 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 52 ; core 0 of 1 ; original_cips tried  0 ; size 202
# _propose_graph: iteration 86 ; core 0 of 6 ; original_cips tried  0 ; size 151
# _propose_graph: iteration 53 ; core 0 of 1 ; original_cips tried  1 ; size 202
# _propose_graph: iteration 87 ; core 0 of 1 ; original_cips tried  1 ; size 151

# %%
colors=['b','g','r','c','m','y','k','w']

# %matplotlib inline
from itertools import islice
import matplotlib.pyplot as plt
import numpy as np
step=1
num_graphs_per_plot=3
num_plots=np.ceil([len(scores)/num_graphs_per_plot])
for i in range(num_plots):
    plt.figure(figsize=(10,5))
    for j,score in enumerate(scores[i*num_graphs_per_plot:i*num_graphs_per_plot+num_graphs_per_plot]):
        data = list(islice(score,None, None, step))
        plt.plot(data,ls='-',color=colors[j], label='graph %d'%(j+i*num_graphs_per_plot+id_start))
        
        # okok now we need to add the infernal evaluation
        seqs=sequences[i*num_graphs_per_plot+j]
        seqs=seqs.split('n')
        
        # SEQUENCES STILL CONTAIN F, ALSO THERE ARE ERRORMESSAGES AT THE END OF INFO
        #seqs=seqs[:-1]
    
        #print seqs
        data2= rna.infernal_checker(seqs,cmfile='../rf00005.cm')
        
        #print data2,seqs
        plt.plot(data2,ls='--',color=colors[j], label='graph %d infernal score'%(j+i*num_graphs_per_plot+id_start))
    
    plt.legend(loc='lower right')
    plt.grid()
    plt.ylim(-0.1,1.1)
    plt.show()

# %%
import graphlearn.abstract_graphs.molecules as mole
from graphlearn.utils import draw
from eden.graph import Vectorizer
v=Vectorizer()
from graphlearn.abstract_graphs.molecules import node_to_cycle
import networkx as nx
import eden

def make_abstract(graph):
    '''
    make sure this is not expanded
    '''
    # prepare fast hash function
    def fhash(stuff):
        return eden.fast_hash(stuff, 2 ** 20 - 1)
    
    
    # all nodes get their cycle calculated
    for n, d in graph.nodes(data=True):
        d['cycle'] = list(node_to_cycle(graph, n))
        d['cycle'].sort()
        #if 'parent'in d:
        #    d.pop('parent')
            

    
    # make sure most of the abstract nodes are created.
    abstract_graph = nx.Graph()
    for n, d in graph.nodes(data=True):
        cyclash = fhash(d['cycle'])
        if cyclash not in abstract_graph.node:
            abstract_graph.add_node(cyclash)
            abstract_graph.node[cyclash]['contracted'] = set(d['cycle'])
            abstract_graph.node[cyclash]['node'] = True
            # it is possible that a node belongs to more than 1 cycle, so...
            # each node gets parents
            for e in d['cycle']:
                node = graph.node[e]
                if 'parent' not in node:
                    node['parent'] = set()
                node['parent'].add(cyclash)


    
    #  HERE THE ACTUAL ABSTRACTION BEGINS

    # connect nodes in the abstract graph
    get_element = lambda x: list(x)[0]


    
    # FOR ALL ABSTRACT NODES
    for n, d in abstract_graph.nodes(data=True):
        # FIND A LABEL
        if len(d['contracted']) > 1:
            labels = [ord(graph.node[childid]['label']) for childid in d['contracted']]
            labels.sort()
            d['label'] = "cycle" #fhash(labels)

        else:
            d['label'] = graph.node[get_element(d['contracted'])]['label']

      
 
        # THEN LOOK AT ALL CONTRACTED NODES TO FIND OUT WHAT CONNECTION WE HAVE TO OUR NEIGHBORS
        for base_node in d['contracted']:
            base_neighbors = graph.neighbors(base_node)
            # for all the neighbors
            for neigh in base_neighbors:
                
                
                # find out if we have to build a connector node
                if len(graph.node[neigh]['cycle']) > 1 and len(d['contracted']) > 1:

                    for other in graph.node[neigh]['parent']:
                        if other != n:
                            l = [other, n]
                            l.sort()
                            connector = fhash(l)
                            
                            
                            shared_nodes = abstract_graph.node[other]['contracted'] & d['contracted']
                            if len(shared_nodes)==0:
                                label='e'
                            else:
                                labels = [ord(graph.node[sid]['label']) for sid in shared_nodes]
                                labels.sort()
                                share_hash = fhash(labels)
                                label='share:'+str(share_hash)
                            abstract_graph.add_edge(other,n,label=label)
                            '''
                            if connector not in abstract_graph.node:
                                # we need to consider making the edge the actual intersect of the two...

                                abstract_graph.add_node(connector)
                                abstract_graph.node[connector]['edge'] = True

                                # abstract_graph.node[connector]['label']='edge'
                                shared_nodes = abstract_graph.node[other]['contracted'] & d['contracted']
                                labels = [ord(graph.node[sid]['label']) for sid in shared_nodes]
                                labels.sort()
                                share_hash = fhash(labels)


                                abstract_graph.node[connector]['label'] = "shared" + str(share_hash)

                                abstract_graph.add_edge(other, connector)
                                abstract_graph.add_edge(connector, n)
                            '''
                else:
                    for e in graph.node[neigh]['parent']:
                        abstract_graph.add_edge(n, e, label='e')
    return abstract_graph




def graphor(base,abstr,nested=True):
    g= nx.disjoint_union(base, abstr)
    node_id= len(g)

    for n,d in g.nodes(data=True):
        if 'contracted' in d and 'edge' not in d:
            for e in d['contracted']:
                if 'edge' not in g.node[e]:
                    # we want an edge from n to e
                    g.add_node(node_id,edge=True,label='e')
                    g.add_edge( n, node_id, nesting=True)
                    g.add_edge( node_id, e, nesting=True)
                    #g.add_edge( n, e, nesting=True)
                    node_id+=1
    return g
    


gr=get_graphs()
for i in range(1):
    g=gr.next()
    ab=make_abstract(g)
    
    g=v._edge_to_vertex_transform(g)
    ab=v._edge_to_vertex_transform(ab)
    zz=graphor(g,ab)
    draw.graphlearn([g,ab], size=20)
    v.transform_single(zz)

# %%
import itertools
l=[1,2,3]
for e in itertools.islice(l,6):
    print e

# %%
import subprocess as sp
def call_folder(filename='NNTMP'):
   
    out = sp.check_output('mlocarna %s | grep "HACK%d\|alifold"' % (filename, 4), shell=True)
    out=out.split('\n')
    seq=out[0].split()[1]
    stru=out[1].split()[1]
    stru=list(stru)
    #stru2=''.join(stru)
  

    # find  deletions
    ids=[]
    for i,c in enumerate(seq):
        if c=='-':
            ids.append(i)

    # take care of deletions
    # remove brackets that dont have a partner anymore
    pairdict=_pairs(stru)
    for i in ids:
        if stru[i]!='.':
            stru[pairdict[i]]='.'

    # delete
    ids.reverse()
    for i in ids:
        del stru[i]
        #stru=stru[:i]+stru[i+1:]

    #print seq
    #print stru2
    #print ''.join(stru)

    return ''.join(stru)

call_folder('fold1955')

# %%
s=['GUUGCAUUAGCUCAAUUGGUAGAGCGUUUGUUUUGUAAUCAAAAGGUUUAGAGUUCAACUCUCUAAUGCANUN', 
   'GGAGAGAUGGCCGAGCGGUUCAAGGCGUAGCAUUGGAACUGCUAUGUAGACUUUUGUUUACCGAGGGUUCGAAUCCCUCUCUUUCCG', 
   'AAGAAAUUAGCUCAGUUGGUAGAGCGUUCGUUUUACACACGAAGGUCAGGUGUUCAAAUCACCUAUUUCUUA', 
   'GCCCACUUAGCUCAGAGGUUAGAGCAUCGCAUUUGUAAUGCGAGGGUCAUCGGUUCAAAUCCGAUAGUCGGCU', 
   'GUUGCAUUAGCUCAAUUGGUAGAGCGUUUGUUUUGUAAUCAAAAGGUUUAGAGUUCAACUCUCUAAUGCANUN']

import textwrap
def write_fasta(sequences,filename='asdasd'):
    fasta=''
    for i,s in enumerate(sequences):
        if len(s) > 5:
            seq=s.replace("F","")
            if not rna.is_sequence(seq):
                print 'fail:'+seq
                continue
            seq='\n'.join(textwrap.wrap(seq, width=60))
            fasta+='>HACK%d\n%s\n\n' % (i,seq)
    print fasta
    #with open(filename, 'w') as f:
    #    f.write(fasta)

write_fasta(s,'tmp/test001')
