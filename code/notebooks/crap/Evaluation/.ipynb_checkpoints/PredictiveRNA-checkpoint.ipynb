# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import eden
import matplotlib.pyplot as plt
from eden.util import configure_logging
import logging
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from itertools import tee, chain, islice
import numpy as np
import random
from time import time
import datetime
from graphlearn.graphlearn import Sampler as GraphLearnSampler
from eden.util import fit,estimate
from eden.path import Vectorizer
import random
# get data
from eden.converter.graph.gspan import gspan_to_eden
from itertools import islice
import random
'''
GET RNA DATA
'''

logger = logging.getLogger()
from eden.converter.fasta import fasta_to_sequence
import itertools

def rfam_uri(family_id):
    return 'http://rfam.xfam.org/family/%s/alignment?acc=%s&format=fastau&download=0'%(family_id,family_id)
def rfam_uri(family_id):
    return '%s.fa'%(family_id)
 

from eden.converter.fasta import fasta_to_sequence
def get_sequences_with_names(filename='RF00005.fa'):
    sequences = fasta_to_sequence("../toolsdata/"+filename)
    return sequences


def get_graphs(fname,size):
    graphs=[g for g in get_sequences_with_names(fname)]
    random.shuffle(graphs)
    return graphs[:size]












# permuted get_graphs
from eden.converter.fasta import fasta_to_sequence
import random 
def permute_sequence(st):
    st=list(st)    
    random.shuffle(st)
    return ''.join(st)
def read_and_permute(samples='RF00005.fa'):
    for name,seq in fasta_to_sequence(samples):
        seq=permute_sequence(seq)
        yield (name,seq)

def get_graphs_permuted(fname='RF00005.fa',size=99999):
    graphs=[g for g in read_and_permute("../toolsdata/"+fname)]
    random.shuffle(graphs)
    return graphs[:size]



# formerly:
#get_graphs(dataset_fname, size=100)

# %%
import random
import graphlearn.abstract_graphs.RNA as rna
from  graphlearn.feasibility import FeasibilityChecker as Checker
from graphlearn.estimator import Wrapper as estimatorwrapper
import graphlearn.utils.draw as draw
from graphlearn.graphlearn import Sampler as GLS
import itertools



def fit_sample(graphs, random_state=random.random()):
    '''
    graphs -> more graphs
    '''
    graphs = list(graphs)
    estimator=estimatorwrapper( nu=.5, cv=2, n_jobs=-1)
    sampler=rna.AbstractSampler(radius_list=[0,1],
                                thickness_list=[2], 
                                min_cip_count=1, 
                                min_interface_count=2, 
                                preprocessor=rna.PreProcessor(base_thickness_list=[1],ignore_inserts=True), 
                                postprocessor=rna.PostProcessor(),
                                estimator=estimator
                                #feasibility_checker=feasibility
                               )
    sampler.fit(graphs,grammar_n_jobs=4,grammar_batch_size=1)
    


    
    
    
    logger.info('graph grammar stats:')
    dataset_size, interface_counts, core_counts, cip_counts = sampler.grammar().size()
    logger.info('#instances:%d   #interfaces: %d   #cores: %d   #core-interface-pairs: %d' % (dataset_size, interface_counts, core_counts, cip_counts))
    
    
    graphs = [ b for a ,b in graphs  ]
    
    graphs = sampler.sample(graphs,
                            n_samples=3,
                            batch_size=1,
                            n_steps=50,
                            n_jobs=4,
                            quick_skip_orig_cip=True,
                            probabilistic_core_choice=True,
                            burnin=10,
                            improving_threshold=0.9,
                            improving_linear_start=0.3,
                            max_size_diff=20,
                            accept_min_similarity=0.65,
                            select_cip_max_tries=30,
                            keep_duplicates=False,
                            include_seed=False,
                            backtrack=10,
                            monitor=False)
    result=[]
    for graphlist in graphs:
        result+=graphlist
    # note that this is a list [('',sequ),..]
    return result

# %%
def fit_and_evaluate(pos_original, neg_original,
                     pos_sampled, neg_sampled,
                     pos_test, neg_test,
                     random_state=42):
    '''
    pos + neg orig+sampled testsets -> orig_roc , sampled_roc, augmented_roc
    '''
    
    # create graph sets...orig augmented and sampled
    pos_orig,pos_orig_ = tee(pos_original)
    neg_orig,neg_orig_ = tee(neg_original)
    
    pos_sampled, pos_sampled_ = tee(pos_sampled)
    neg_sampled, neg_sampled_ = tee(neg_sampled)
    
    pos_augmented = chain(pos_orig_,pos_sampled_)
    neg_augmented = chain(neg_orig_,neg_sampled_)

    predictive_performances = []
    for desc,pos_train,neg_train in [('original',pos_orig, neg_orig),
                                     ('sample',pos_sampled,neg_sampled),
                                     ('original+sample',pos_augmented, neg_augmented)]:
        pos_train,pos_train_ = tee(pos_train)
        neg_train,neg_train_ = tee(neg_train)
        pos_size=sum(1 for x in pos_train_)
        neg_size=sum(1 for x in neg_train_)

        logger.info( "-"*80)
        logger.info('working on %s'%(desc))
        logger.info('training set sizes: #pos: %d #neg: %d'%(pos_size, neg_size))

        if pos_size == 0 or neg_size == 0:
            logger.info('WARNING: empty dataset')
            predictive_performances.append(0)            
        else:
            start=time()
            pos_test,pos_test_ = tee(pos_test)
            neg_test,neg_test_ = tee(neg_test)
            
            local_estimator = fit(pos_train, neg_train, Vectorizer(4), n_jobs=-1, n_iter_search=1)
            apr, roc = estimate(pos_test_, neg_test_, local_estimator, Vectorizer(4))
            predictive_performances.append(roc)
            logger.info( 'elapsed: %.1f sec'%(time()-start))
    return predictive_performances

# %%
def evaluate(pos_fname, neg_fname=None, size=None, percentages=None, n_repetitions=None, train_test_split=None):
    # initializing 
    graphs_pos = get_graphs(pos_fname, size=size)
    
    if neg_fname==None:
        graphs_neg = get_graphs_permuted(pos_fname, size=size)
    else:    
        graphs_neg = get_graphs(neg_fname, size=size)

    # train/test split
    from eden.util import random_bipartition_iter
    pos_train_global,pos_test_global = random_bipartition_iter(graphs_pos,train_test_split,random_state=random.random()*1000)
    neg_train_global,neg_test_global = random_bipartition_iter(graphs_neg,train_test_split,random_state=random.random()*1000)


    original_repetitions = []
    original_sample_repetitions = []
    sample_repetitions = []

    for percentage in percentages:
        originals = []
        originals_samples = []
        samples = []
        for repetition in range(n_repetitions):
            random_state = int(313379*percentage+repetition) 
            random.seed(random_state)
            pos_train_global,pos_train_global_ = tee(pos_train_global)
            neg_train_global,neg_train_global_ = tee(neg_train_global)
            pos_test_global,pos_test_global_ = tee(pos_test_global)
            neg_test_global,neg_test_global_ = tee(neg_test_global)

            # use shuffled list to create test and sample set
            pos,pos_reminder = random_bipartition_iter(pos_train_global_,percentage)
            pos,pos_ = tee(pos)
            neg,neg_reminder = random_bipartition_iter(neg_train_global_,percentage)
            neg,neg_ = tee(neg)

            #sample independently from the 2 classes
            logger.info('Positive')
            sampled_pos = fit_sample(pos_, random_state=random_state)
            logger.info('Negative')
            sampled_neg = fit_sample(neg_, random_state=random_state)

            #evaluate the predictive performance on held out test set
            start=time()
            logger.info( "="*80)
            logger.info( 'repetition: %d/%d'%(repetition+1, n_repetitions))
            logger.info( "training percentage:"+str(percentage))
            perf_orig,\
            perf_samp,\
            perf_orig_samp = fit_and_evaluate(pos,neg,
                                              sampled_pos,sampled_neg,
                                              pos_test_global_,neg_test_global_)
            logger.info( 'Time elapsed for full repetition: %.1f sec'%((time()-start)))
            originals.append(perf_orig)
            originals_samples.append(perf_orig_samp)
            samples.append(perf_samp)

        original_repetitions.append(originals)
        original_sample_repetitions.append(originals_samples)
        sample_repetitions.append(samples)
    
    return original_repetitions, original_sample_repetitions, sample_repetitions

# %%
def plot(dataset, percentages, original_sample_repetitions, original_repetitions, sample_repetitions):
    gc={'color':'g'}
    rc={'color':'r'}
    bc={'color':'b'}
    ws = 0.02
    os = np.mean(original_sample_repetitions, axis=1)
    o = np.mean(original_repetitions, axis=1)
    s = np.mean(sample_repetitions, axis=1)
    plt.figure(figsize=(18,8))
    plt.grid()
    plt.boxplot(original_sample_repetitions, positions=percentages, widths=ws, capprops=gc, medianprops=gc, boxprops=gc, whiskerprops=gc, flierprops=gc)
    plt.plot(percentages,os, color='g', marker='o', markeredgewidth=1, markersize=7, markeredgecolor='g', markerfacecolor='w', label='original+sample')

    plt.boxplot(original_repetitions, positions=percentages, widths=ws, capprops=rc, medianprops=rc, boxprops=rc, whiskerprops=rc, flierprops=rc)
    plt.plot(percentages,o, color='r', marker='o', markeredgewidth=1, markersize=7, markeredgecolor='r', markerfacecolor='w', label='original')

    plt.boxplot(sample_repetitions, positions=percentages, widths=ws, capprops=bc, medianprops=bc, boxprops=bc, whiskerprops=bc, flierprops=bc)
    plt.plot(percentages,s, color='b', marker='o', markeredgewidth=1, markersize=7, markeredgecolor='b', markerfacecolor='w', label='sample')

    plt.xlim(percentages[0]-.05,percentages[-1]+.05)
    plt.title(dataset+'\n',fontsize=17)
    plt.legend(loc='lower right',fontsize=16)
    plt.ylabel('ROC AUC',fontsize=16)
    plt.xlabel('Dataset size (fraction)',fontsize=16)
    plt.savefig('%s_plot_predictive_performance_of_samples.pdf' % dataset)

# %%
def save_results(result_fname,percentages, original_repetitions,original_sample_repetitions,sample_repetitions):
    with open(result_fname,'w') as f:
        f.write('dataset sizes list:\n')
        for perc in percentages:
            f.write('%s '% perc)
        f.write('\n')
        f.write('AUC scores:\n')
        for repetitions in original_repetitions,original_sample_repetitions,sample_repetitions:
            f.write('%s\n' % len(repetitions))
            for repetition in repetitions:
                for auc in repetition:
                    f.write('%s ' % auc)
                f.write('\n')
    
def load_results(result_fname):
    with open(result_fname) as f:
        comment = next(f)
        line = next(f)
        percentages = [float(x) for x in line.split()]
        comment = next(f)

        original_repetitions = []
        size = int(next(f))
        for i in range(size):
            line = next(f)
            repetition = [float(x) for x in line.split()]
            original_repetitions.append(repetition)

        original_sample_repetitions = []
        size = int(next(f))
        for i in range(size):
            line = next(f)
            repetition = [float(x) for x in line.split()]
            original_sample_repetitions.append(repetition)


        sample_repetitions = []
        size = int(next(f))
        for i in range(size):
            line = next(f)
            repetition = [float(x) for x in line.split()]
            sample_repetitions.append(repetition)
            
    return percentages, original_repetitions,original_sample_repetitions,sample_repetitions

# %% [markdown]
# #Experimental pipeline

# %%
#plot("RF00162 vs RF01725", percentages_l, original_sample_repetitions_l, original_repetitions_l, sample_repetitions_l)

# %%
def do():
    #special case: bursi
    pos_dataset_fname = 'RF00005.fa'
    neg_dataset_fname = None # none will permute the first dataset
    dataset='%s_vs_%s' % (pos_dataset_fname, neg_dataset_fname)
    result_fname='%s_predictive_performance_of_samples.data'%dataset
    result_fname = 'asd.data'
    if False:
        #logging
        
        if True:
            logger_fname = '%s_predictive_performance_of_samples.log'%dataset
        else:
            logger_fname = None
        configure_logging(logger,verbosity=1, filename=logger_fname)

        #main 
        start=time()
        print( 'Working with dataset: %s' % dataset )

        logger.info( 'Working with dataset: %s' % dataset )

        percentages=[.08,.2,.4,.6,.8,.95]
        percentages=[.07,0.1,0.15,0.2]

        # set size to 900 in production
        original_repetitions,\
        original_sample_repetitions,\
        sample_repetitions = evaluate(pos_dataset_fname,
                                      neg_dataset_fname,
                                      size=100,
                                      percentages=percentages,
                                      n_repetitions=5,
                                      train_test_split=0.7)
        #save and display results
        save_results(result_fname,percentages, original_repetitions,original_sample_repetitions,sample_repetitions)    

    
    percentages_l, original_repetitions_l,original_sample_repetitions_l,sample_repetitions_l = load_results(result_fname)
    plot(dataset, percentages_l, original_sample_repetitions_l, original_repetitions_l, sample_repetitions_l)

    print('Time elapsed: %s'%(datetime.timedelta(seconds=(time() - start))))

do()
# Out:
# Working with dataset: RF00005.fa_vs_None
# Working with dataset: RF00005.fa_vs_None
# Positive
# graph grammar stats:
# #instances:4   #interfaces: 3   #cores: 6   #core-interface-pairs: 6
# Negative
# graph grammar stats:
# #instances:4   #interfaces: 2   #cores: 5   #core-interface-pairs: 5
# ================================================================================
# repetition: 1/5
# training percentage:0.07
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 4 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.72      0.60      0.65        30
#           1       0.66      0.77      0.71        30
#
# avg / total       0.69      0.68      0.68        60
#
# APR: 0.714
# ROC: 0.734
# Cross-validated estimate
#             accuracy: 0.867 +- 0.067
#            precision: 0.914 +- 0.114
#               recall: 0.833 +- 0.105
#                   f1: 0.862 +- 0.064
#    average_precision: 0.948 +- 0.042
#              roc_auc: 0.928 +- 0.060
# elapsed: 5.5 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 1 #neg: 0
# WARNING: empty dataset
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 5 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.69      0.67      0.68        30
#           1       0.68      0.70      0.69        30
#
# avg / total       0.68      0.68      0.68        60
#
# APR: 0.704
# ROC: 0.721
# Cross-validated estimate
#             accuracy: 0.817 +- 0.062
#            precision: 0.853 +- 0.075
#               recall: 0.767 +- 0.082
#                   f1: 0.806 +- 0.070
#    average_precision: 0.926 +- 0.060
#              roc_auc: 0.906 +- 0.085
# elapsed: 5.4 sec
# Time elapsed for full repetition: 10.9 sec
# Positive
# graph grammar stats:
# #instances:4   #interfaces: 3   #cores: 6   #core-interface-pairs: 6
# Negative
# graph grammar stats:
# #instances:4   #interfaces: 2   #cores: 5   #core-interface-pairs: 5
# ================================================================================
# repetition: 2/5
# training percentage:0.07
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 4 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.91      0.33      0.49        30
#           1       0.59      0.97      0.73        30
#
# avg / total       0.75      0.65      0.61        60
#
# APR: 0.683
# ROC: 0.704
# Cross-validated estimate
#             accuracy: 0.850 +- 0.033
#            precision: 0.917 +- 0.105
#               recall: 0.800 +- 0.125
#                   f1: 0.840 +- 0.041
#    average_precision: 0.938 +- 0.053
#              roc_auc: 0.917 +- 0.088
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 1 #neg: 0
# WARNING: empty dataset
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 5 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.93      0.47      0.62        30
#           1       0.64      0.97      0.77        30
#
# avg / total       0.79      0.72      0.70        60
#
# APR: 0.785
# ROC: 0.782
# Cross-validated estimate
#             accuracy: 0.833 +- 0.091
#            precision: 0.843 +- 0.106
#               recall: 0.833 +- 0.149
#                   f1: 0.829 +- 0.095
#    average_precision: 0.923 +- 0.056
#              roc_auc: 0.889 +- 0.105
# elapsed: 4.9 sec
# Time elapsed for full repetition: 9.8 sec
# Positive
# graph grammar stats:
# #instances:4   #interfaces: 3   #cores: 6   #core-interface-pairs: 6
# Negative
# graph grammar stats:
# #instances:4   #interfaces: 2   #cores: 5   #core-interface-pairs: 5
# ================================================================================
# repetition: 3/5
# training percentage:0.07
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 4 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.85      0.37      0.51        30
#           1       0.60      0.93      0.73        30
#
# avg / total       0.72      0.65      0.62        60
#
# APR: 0.681
# ROC: 0.709
# Cross-validated estimate
#             accuracy: 0.850 +- 0.097
#            precision: 0.950 +- 0.100
#               recall: 0.733 +- 0.133
#                   f1: 0.825 +- 0.120
#    average_precision: 0.922 +- 0.068
#              roc_auc: 0.894 +- 0.098
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 1 #neg: 0
# WARNING: empty dataset
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 5 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.84      0.53      0.65        30
#           1       0.66      0.90      0.76        30
#
# avg / total       0.75      0.72      0.71        60
#
# APR: 0.738
# ROC: 0.750
# Cross-validated estimate
#             accuracy: 0.833 +- 0.053
#            precision: 0.876 +- 0.110
#               recall: 0.800 +- 0.067
#                   f1: 0.829 +- 0.047
#    average_precision: 0.941 +- 0.018
#              roc_auc: 0.917 +- 0.043
# elapsed: 4.9 sec
# Time elapsed for full repetition: 9.8 sec
# Positive
# graph grammar stats:
# #instances:4   #interfaces: 3   #cores: 6   #core-interface-pairs: 6
# Negative
# graph grammar stats:
# #instances:4   #interfaces: 2   #cores: 5   #core-interface-pairs: 5
# ================================================================================
# repetition: 4/5
# training percentage:0.07
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 4 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.91      0.33      0.49        30
#           1       0.59      0.97      0.73        30
#
# avg / total       0.75      0.65      0.61        60
#
# APR: 0.732
# ROC: 0.761
# Cross-validated estimate
#             accuracy: 0.833 +- 0.053
#            precision: 0.898 +- 0.085
#               recall: 0.767 +- 0.133
#                   f1: 0.817 +- 0.063
#    average_precision: 0.915 +- 0.053
#              roc_auc: 0.889 +- 0.079
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 2 #neg: 0
# WARNING: empty dataset
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 6 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.66      0.83      0.74        30
#           1       0.77      0.57      0.65        30
#
# avg / total       0.72      0.70      0.69        60
#
# APR: 0.865
# ROC: 0.849
# Cross-validated estimate
#             accuracy: 0.883 +- 0.067
#            precision: 0.967 +- 0.067
#               recall: 0.800 +- 0.125
#                   f1: 0.868 +- 0.077
#    average_precision: 0.947 +- 0.046
#              roc_auc: 0.928 +- 0.067
# elapsed: 4.9 sec
# Time elapsed for full repetition: 9.9 sec
# Positive
# graph grammar stats:
# #instances:4   #interfaces: 3   #cores: 6   #core-interface-pairs: 6
# Negative
# graph grammar stats:
# #instances:4   #interfaces: 2   #cores: 5   #core-interface-pairs: 5
# ================================================================================
# repetition: 5/5
# training percentage:0.07
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 4 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.80      0.40      0.53        30
#           1       0.60      0.90      0.72        30
#
# avg / total       0.70      0.65      0.63        60
#
# APR: 0.675
# ROC: 0.688
# Cross-validated estimate
#             accuracy: 0.800 +- 0.085
#            precision: 0.877 +- 0.104
#               recall: 0.700 +- 0.125
#                   f1: 0.774 +- 0.105
#    average_precision: 0.934 +- 0.031
#              roc_auc: 0.922 +- 0.048
# elapsed: 5.0 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 2 #neg: 0
# WARNING: empty dataset
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 6 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.52      0.93      0.67        30
#           1       0.67      0.13      0.22        30
#
# avg / total       0.59      0.53      0.44        60
#
# APR: 0.654
# ROC: 0.689
# Cross-validated estimate
#             accuracy: 0.867 +- 0.067
#            precision: 0.903 +- 0.082
#               recall: 0.833 +- 0.149
#                   f1: 0.857 +- 0.079
#    average_precision: 0.947 +- 0.047
#              roc_auc: 0.928 +- 0.067
# elapsed: 5.1 sec
# Time elapsed for full repetition: 10.1 sec
# Positive
# graph grammar stats:
# #instances:7   #interfaces: 10   #cores: 28   #core-interface-pairs: 28
# Negative
# graph grammar stats:
# #instances:7   #interfaces: 5   #cores: 13   #core-interface-pairs: 13
# ================================================================================
# repetition: 1/5
# training percentage:0.1
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 7 #neg: 7
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.94      0.50      0.65        30
#           1       0.66      0.97      0.78        30
#
# avg / total       0.80      0.73      0.72        60
#
# APR: 0.753
# ROC: 0.764
# Cross-validated estimate
#             accuracy: 0.850 +- 0.033
#            precision: 0.933 +- 0.082
#               recall: 0.767 +- 0.082
#                   f1: 0.835 +- 0.040
#    average_precision: 0.952 +- 0.028
#              roc_auc: 0.944 +- 0.030
# elapsed: 5.0 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 6 #neg: 3
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.48      0.80      0.60        30
#           1       0.40      0.13      0.20        30
#
# avg / total       0.44      0.47      0.40        60
#
# APR: 0.483
# ROC: 0.543
# Cross-validated estimate
#             accuracy: 0.833 +- 0.053
#            precision: 0.927 +- 0.090
#               recall: 0.733 +- 0.082
#                   f1: 0.814 +- 0.059
#    average_precision: 0.930 +- 0.056
#              roc_auc: 0.906 +- 0.085
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 13 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.51      0.83      0.63        30
#           1       0.55      0.20      0.29        30
#
# avg / total       0.53      0.52      0.46        60
#
# APR: 0.645
# ROC: 0.694
# Cross-validated estimate
#             accuracy: 0.833 +- 0.091
#            precision: 0.896 +- 0.147
#               recall: 0.800 +- 0.125
#                   f1: 0.829 +- 0.078
#    average_precision: 0.937 +- 0.036
#              roc_auc: 0.917 +- 0.063
# elapsed: 4.9 sec
# Time elapsed for full repetition: 14.8 sec
# Positive
# graph grammar stats:
# #instances:7   #interfaces: 10   #cores: 28   #core-interface-pairs: 28
# Negative
# graph grammar stats:
# #instances:7   #interfaces: 5   #cores: 13   #core-interface-pairs: 13
# ================================================================================
# repetition: 2/5
# training percentage:0.1
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 7 #neg: 7
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.86      0.60      0.71        30
#           1       0.69      0.90      0.78        30
#
# avg / total       0.77      0.75      0.74        60
#
# APR: 0.761
# ROC: 0.771
# Cross-validated estimate
#             accuracy: 0.850 +- 0.111
#            precision: 0.892 +- 0.148
#               recall: 0.833 +- 0.105
#                   f1: 0.851 +- 0.097
#    average_precision: 0.931 +- 0.051
#              roc_auc: 0.906 +- 0.074
# elapsed: 5.0 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 8 #neg: 1
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.53      0.97      0.68        30
#           1       0.80      0.13      0.23        30
#
# avg / total       0.66      0.55      0.46        60
#
# APR: 0.608
# ROC: 0.509
# Cross-validated estimate
#             accuracy: 0.833 +- 0.091
#            precision: 0.905 +- 0.131
#               recall: 0.767 +- 0.133
#                   f1: 0.820 +- 0.093
#    average_precision: 0.928 +- 0.059
#              roc_auc: 0.900 +- 0.082
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 15 #neg: 8
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.55      1.00      0.71        30
#           1       1.00      0.17      0.29        30
#
# avg / total       0.77      0.58      0.50        60
#
# APR: 0.778
# ROC: 0.762
# Cross-validated estimate
#             accuracy: 0.783 +- 0.067
#            precision: 0.813 +- 0.128
#               recall: 0.800 +- 0.125
#                   f1: 0.789 +- 0.043
#    average_precision: 0.932 +- 0.060
#              roc_auc: 0.900 +- 0.100
# elapsed: 4.9 sec
# Time elapsed for full repetition: 14.8 sec
# Positive
# graph grammar stats:
# #instances:7   #interfaces: 10   #cores: 28   #core-interface-pairs: 28
# Negative
# graph grammar stats:
# #instances:7   #interfaces: 5   #cores: 13   #core-interface-pairs: 13
# ================================================================================
# repetition: 3/5
# training percentage:0.1
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 7 #neg: 7
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       1.00      0.33      0.50        30
#           1       0.60      1.00      0.75        30
#
# avg / total       0.80      0.67      0.62        60
#
# APR: 0.800
# ROC: 0.787
# Cross-validated estimate
#             accuracy: 0.883 +- 0.041
#            precision: 0.967 +- 0.067
#               recall: 0.800 +- 0.067
#                   f1: 0.872 +- 0.046
#    average_precision: 0.949 +- 0.061
#              roc_auc: 0.922 +- 0.103
# elapsed: 5.6 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 8 #neg: 3
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.48      0.80      0.60        30
#           1       0.40      0.13      0.20        30
#
# avg / total       0.44      0.47      0.40        60
#
# APR: 0.578
# ROC: 0.582
# Cross-validated estimate
#             accuracy: 0.900 +- 0.062
#            precision: 0.938 +- 0.076
#               recall: 0.867 +- 0.125
#                   f1: 0.893 +- 0.070
#    average_precision: 0.954 +- 0.055
#              roc_auc: 0.933 +- 0.084
# elapsed: 5.7 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 15 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.55      1.00      0.71        30
#           1       1.00      0.17      0.29        30
#
# avg / total       0.77      0.58      0.50        60
#
# APR: 0.814
# ROC: 0.806
# Cross-validated estimate
#             accuracy: 0.800 +- 0.125
#            precision: 0.811 +- 0.178
#               recall: 0.867 +- 0.067
#                   f1: 0.824 +- 0.089
#    average_precision: 0.932 +- 0.050
#              roc_auc: 0.911 +- 0.064
# elapsed: 5.1 sec
# Time elapsed for full repetition: 16.4 sec
# Positive
# graph grammar stats:
# #instances:7   #interfaces: 10   #cores: 28   #core-interface-pairs: 28
# Negative
# graph grammar stats:
# #instances:7   #interfaces: 5   #cores: 13   #core-interface-pairs: 13
# ================================================================================
# repetition: 4/5
# training percentage:0.1
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 7 #neg: 7
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.86      0.60      0.71        30
#           1       0.69      0.90      0.78        30
#
# avg / total       0.77      0.75      0.74        60
#
# APR: 0.710
# ROC: 0.743
# Cross-validated estimate
#             accuracy: 0.867 +- 0.067
#            precision: 0.931 +- 0.086
#               recall: 0.800 +- 0.125
#                   f1: 0.854 +- 0.077
#    average_precision: 0.935 +- 0.057
#              roc_auc: 0.900 +- 0.097
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 8 #neg: 3
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.49      0.70      0.58        30
#           1       0.47      0.27      0.34        30
#
# avg / total       0.48      0.48      0.46        60
#
# APR: 0.513
# ROC: 0.587
# Cross-validated estimate
#             accuracy: 0.850 +- 0.082
#            precision: 0.927 +- 0.090
#               recall: 0.767 +- 0.133
#                   f1: 0.832 +- 0.091
#    average_precision: 0.945 +- 0.068
#              roc_auc: 0.928 +- 0.092
# elapsed: 4.8 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 15 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.53      0.97      0.68        30
#           1       0.80      0.13      0.23        30
#
# avg / total       0.66      0.55      0.46        60
#
# APR: 0.669
# ROC: 0.704
# Cross-validated estimate
#             accuracy: 0.833 +- 0.105
#            precision: 0.850 +- 0.133
#               recall: 0.833 +- 0.149
#                   f1: 0.831 +- 0.107
#    average_precision: 0.947 +- 0.055
#              roc_auc: 0.922 +- 0.085
# elapsed: 4.9 sec
# Time elapsed for full repetition: 14.7 sec
# Positive
# graph grammar stats:
# #instances:7   #interfaces: 10   #cores: 28   #core-interface-pairs: 28
# Negative
# graph grammar stats:
# #instances:7   #interfaces: 5   #cores: 13   #core-interface-pairs: 13
# ================================================================================
# repetition: 5/5
# training percentage:0.1
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 7 #neg: 7
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.94      0.53      0.68        30
#           1       0.67      0.97      0.79        30
#
# avg / total       0.81      0.75      0.74        60
#
# APR: 0.821
# ROC: 0.808
# Cross-validated estimate
#             accuracy: 0.833 +- 0.118
#            precision: 0.852 +- 0.140
#               recall: 0.833 +- 0.105
#                   f1: 0.837 +- 0.109
#    average_precision: 0.950 +- 0.038
#              roc_auc: 0.933 +- 0.052
# elapsed: 5.0 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 6 #neg: 3
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.50      1.00      0.67        30
#           1       0.00      0.00      0.00        30
#
# avg / total       0.25      0.50      0.33        60
#
# APR: 0.546
# ROC: 0.596
# Cross-validated estimate
#             accuracy: 0.867 +- 0.041
#            precision: 0.905 +- 0.078
#               recall: 0.833 +- 0.105
#                   f1: 0.860 +- 0.048
#    average_precision: 0.928 +- 0.069
#              roc_auc: 0.900 +- 0.108
# elapsed: 5.6 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 13 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.58      0.97      0.72        30
#           1       0.90      0.30      0.45        30
#
# avg / total       0.74      0.63      0.59        60
#
# APR: 0.800
# ROC: 0.787
# Cross-validated estimate
#             accuracy: 0.850 +- 0.097
#            precision: 0.874 +- 0.112
#               recall: 0.833 +- 0.149
#                   f1: 0.844 +- 0.102
#    average_precision: 0.939 +- 0.055
#              roc_auc: 0.917 +- 0.075
# elapsed: 4.9 sec
# Time elapsed for full repetition: 15.5 sec
# Positive
# graph grammar stats:
# #instances:10   #interfaces: 19   #cores: 61   #core-interface-pairs: 61
# Negative
# graph grammar stats:
# #instances:10   #interfaces: 15   #cores: 40   #core-interface-pairs: 40
# ================================================================================
# repetition: 1/5
# training percentage:0.15
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 10 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.81      0.43      0.57        30
#           1       0.61      0.90      0.73        30
#
# avg / total       0.71      0.67      0.65        60
#
# APR: 0.857
# ROC: 0.791
# Cross-validated estimate
#             accuracy: 0.850 +- 0.062
#            precision: 0.931 +- 0.086
#               recall: 0.767 +- 0.133
#                   f1: 0.832 +- 0.074
#    average_precision: 0.913 +- 0.058
#              roc_auc: 0.883 +- 0.095
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 15 #neg: 6
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.54      1.00      0.70        30
#           1       1.00      0.13      0.24        30
#
# avg / total       0.77      0.57      0.47        60
#
# APR: 0.718
# ROC: 0.618
# Cross-validated estimate
#             accuracy: 0.850 +- 0.062
#            precision: 0.910 +- 0.117
#               recall: 0.800 +- 0.067
#                   f1: 0.844 +- 0.057
#    average_precision: 0.945 +- 0.054
#              roc_auc: 0.917 +- 0.091
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 25 #neg: 16
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.68      1.00      0.81        30
#           1       1.00      0.53      0.70        30
#
# avg / total       0.84      0.77      0.75        60
#
# APR: 0.834
# ROC: 0.737
# Cross-validated estimate
#             accuracy: 0.817 +- 0.062
#            precision: 0.960 +- 0.080
#               recall: 0.667 +- 0.105
#                   f1: 0.781 +- 0.081
#    average_precision: 0.932 +- 0.052
#              roc_auc: 0.911 +- 0.077
# elapsed: 5.0 sec
# Time elapsed for full repetition: 14.9 sec
# Positive
# graph grammar stats:
# #instances:10   #interfaces: 19   #cores: 61   #core-interface-pairs: 61
# Negative
# graph grammar stats:
# #instances:10   #interfaces: 15   #cores: 40   #core-interface-pairs: 40
# ================================================================================
# repetition: 2/5
# training percentage:0.15
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 10 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.75      0.40      0.52        30
#           1       0.59      0.87      0.70        30
#
# avg / total       0.67      0.63      0.61        60
#
# APR: 0.880
# ROC: 0.824
# Cross-validated estimate
#             accuracy: 0.867 +- 0.085
#            precision: 1.000 +- 0.000
#               recall: 0.733 +- 0.170
#                   f1: 0.835 +- 0.113
#    average_precision: 0.948 +- 0.057
#              roc_auc: 0.928 +- 0.085
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 15 #neg: 6
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.54      1.00      0.70        30
#           1       1.00      0.13      0.24        30
#
# avg / total       0.77      0.57      0.47        60
#
# APR: 0.781
# ROC: 0.660
# Cross-validated estimate
#             accuracy: 0.883 +- 0.067
#            precision: 0.967 +- 0.067
#               recall: 0.800 +- 0.125
#                   f1: 0.868 +- 0.077
#    average_precision: 0.956 +- 0.047
#              roc_auc: 0.939 +- 0.067
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 25 #neg: 16
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.69      0.97      0.81        30
#           1       0.94      0.57      0.71        30
#
# avg / total       0.82      0.77      0.76        60
#
# APR: 0.880
# ROC: 0.833
# Cross-validated estimate
#             accuracy: 0.833 +- 0.053
#            precision: 0.898 +- 0.085
#               recall: 0.767 +- 0.133
#                   f1: 0.817 +- 0.063
#    average_precision: 0.930 +- 0.054
#              roc_auc: 0.900 +- 0.096
# elapsed: 5.0 sec
# Time elapsed for full repetition: 14.8 sec
# Positive
# graph grammar stats:
# #instances:10   #interfaces: 19   #cores: 61   #core-interface-pairs: 61
# Negative
# graph grammar stats:
# #instances:10   #interfaces: 15   #cores: 40   #core-interface-pairs: 40
# ================================================================================
# repetition: 3/5
# training percentage:0.15
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 10 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.70      0.53      0.60        30
#           1       0.62      0.77      0.69        30
#
# avg / total       0.66      0.65      0.65        60
#
# APR: 0.862
# ROC: 0.796
# Cross-validated estimate
#             accuracy: 0.867 +- 0.041
#            precision: 0.938 +- 0.076
#               recall: 0.800 +- 0.125
#                   f1: 0.853 +- 0.053
#    average_precision: 0.927 +- 0.042
#              roc_auc: 0.900 +- 0.067
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 13 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.54      0.47      0.50        30
#           1       0.53      0.60      0.56        30
#
# avg / total       0.53      0.53      0.53        60
#
# APR: 0.720
# ROC: 0.638
# Cross-validated estimate
#             accuracy: 0.883 +- 0.041
#            precision: 0.967 +- 0.067
#               recall: 0.800 +- 0.067
#                   f1: 0.872 +- 0.046
#    average_precision: 0.946 +- 0.055
#              roc_auc: 0.922 +- 0.090
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 23 #neg: 14
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.71      1.00      0.83        30
#           1       1.00      0.60      0.75        30
#
# avg / total       0.86      0.80      0.79        60
#
# APR: 0.885
# ROC: 0.836
# Cross-validated estimate
#             accuracy: 0.817 +- 0.062
#            precision: 0.960 +- 0.080
#               recall: 0.667 +- 0.105
#                   f1: 0.781 +- 0.081
#    average_precision: 0.943 +- 0.044
#              roc_auc: 0.922 +- 0.069
# elapsed: 4.9 sec
# Time elapsed for full repetition: 14.7 sec
# Positive
# graph grammar stats:
# #instances:10   #interfaces: 19   #cores: 61   #core-interface-pairs: 61
# Negative
# graph grammar stats:
# #instances:10   #interfaces: 15   #cores: 40   #core-interface-pairs: 40
# ================================================================================
# repetition: 4/5
# training percentage:0.15
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 10 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.75      0.50      0.60        30
#           1       0.62      0.83      0.71        30
#
# avg / total       0.69      0.67      0.66        60
#
# APR: 0.881
# ROC: 0.823
# Cross-validated estimate
#             accuracy: 0.783 +- 0.067
#            precision: 0.806 +- 0.104
#               recall: 0.767 +- 0.082
#                   f1: 0.780 +- 0.067
#    average_precision: 0.933 +- 0.055
#              roc_auc: 0.900 +- 0.096
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 13 #neg: 4
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.61      0.93      0.74        30
#           1       0.86      0.40      0.55        30
#
# avg / total       0.73      0.67      0.64        60
#
# APR: 0.785
# ROC: 0.690
# Cross-validated estimate
#             accuracy: 0.850 +- 0.082
#            precision: 0.960 +- 0.080
#               recall: 0.733 +- 0.133
#                   f1: 0.825 +- 0.092
#    average_precision: 0.950 +- 0.062
#              roc_auc: 0.933 +- 0.082
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 23 #neg: 14
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.72      0.97      0.83        30
#           1       0.95      0.63      0.76        30
#
# avg / total       0.84      0.80      0.79        60
#
# APR: 0.882
# ROC: 0.829
# Cross-validated estimate
#             accuracy: 0.850 +- 0.097
#            precision: 0.925 +- 0.150
#               recall: 0.800 +- 0.067
#                   f1: 0.848 +- 0.079
#    average_precision: 0.921 +- 0.054
#              roc_auc: 0.894 +- 0.083
# elapsed: 4.9 sec
# Time elapsed for full repetition: 14.7 sec
# Positive
# graph grammar stats:
# #instances:10   #interfaces: 19   #cores: 61   #core-interface-pairs: 61
# Negative
# graph grammar stats:
# #instances:10   #interfaces: 15   #cores: 40   #core-interface-pairs: 40
# ================================================================================
# repetition: 5/5
# training percentage:0.15
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 10 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.76      0.63      0.69        30
#           1       0.69      0.80      0.74        30
#
# avg / total       0.72      0.72      0.71        60
#
# APR: 0.867
# ROC: 0.811
# Cross-validated estimate
#             accuracy: 0.817 +- 0.062
#            precision: 0.853 +- 0.123
#               recall: 0.800 +- 0.125
#                   f1: 0.813 +- 0.064
#    average_precision: 0.928 +- 0.052
#              roc_auc: 0.894 +- 0.085
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 15 #neg: 5
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.64      0.77      0.70        30
#           1       0.71      0.57      0.63        30
#
# avg / total       0.67      0.67      0.66        60
#
# APR: 0.751
# ROC: 0.647
# Cross-validated estimate
#             accuracy: 0.800 +- 0.067
#            precision: 0.920 +- 0.098
#               recall: 0.667 +- 0.105
#                   f1: 0.766 +- 0.083
#    average_precision: 0.921 +- 0.046
#              roc_auc: 0.889 +- 0.072
# elapsed: 4.8 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 25 #neg: 15
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.69      0.90      0.78        30
#           1       0.86      0.60      0.71        30
#
# avg / total       0.77      0.75      0.74        60
#
# APR: 0.843
# ROC: 0.769
# Cross-validated estimate
#             accuracy: 0.883 +- 0.041
#            precision: 0.971 +- 0.057
#               recall: 0.800 +- 0.125
#                   f1: 0.868 +- 0.056
#    average_precision: 0.955 +- 0.050
#              roc_auc: 0.933 +- 0.076
# elapsed: 5.0 sec
# Time elapsed for full repetition: 14.8 sec
# Positive
# graph grammar stats:
# #instances:14   #interfaces: 28   #cores: 99   #core-interface-pairs: 99
# Negative
# graph grammar stats:
# #instances:14   #interfaces: 25   #cores: 65   #core-interface-pairs: 70
# ================================================================================
# repetition: 1/5
# training percentage:0.2
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 14 #neg: 14
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.84      0.70      0.76        30
#           1       0.74      0.87      0.80        30
#
# avg / total       0.79      0.78      0.78        60
#
# APR: 0.892
# ROC: 0.868
# Cross-validated estimate
#             accuracy: 0.800 +- 0.067
#            precision: 0.808 +- 0.117
#               recall: 0.833 +- 0.149
#                   f1: 0.804 +- 0.065
#    average_precision: 0.922 +- 0.068
#              roc_auc: 0.894 +- 0.098
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 27 #neg: 14
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.79      0.87      0.83        30
#           1       0.85      0.77      0.81        30
#
# avg / total       0.82      0.82      0.82        60
#
# APR: 0.891
# ROC: 0.851
# Cross-validated estimate
#             accuracy: 0.833 +- 0.053
#            precision: 0.910 +- 0.117
#               recall: 0.767 +- 0.082
#                   f1: 0.822 +- 0.048
#    average_precision: 0.928 +- 0.061
#              roc_auc: 0.906 +- 0.085
# elapsed: 5.0 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 41 #neg: 28
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.75      1.00      0.86        30
#           1       1.00      0.67      0.80        30
#
# avg / total       0.88      0.83      0.83        60
#
# APR: 0.890
# ROC: 0.846
# Cross-validated estimate
#             accuracy: 0.833 +- 0.053
#            precision: 0.843 +- 0.084
#               recall: 0.833 +- 0.105
#                   f1: 0.832 +- 0.059
#    average_precision: 0.917 +- 0.042
#              roc_auc: 0.889 +- 0.077
# elapsed: 5.1 sec
# Time elapsed for full repetition: 15.1 sec
# Positive
# graph grammar stats:
# #instances:14   #interfaces: 28   #cores: 99   #core-interface-pairs: 99
# Negative
# graph grammar stats:
# #instances:14   #interfaces: 25   #cores: 65   #core-interface-pairs: 70
# ================================================================================
# repetition: 2/5
# training percentage:0.2
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 14 #neg: 14
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.84      0.53      0.65        30
#           1       0.66      0.90      0.76        30
#
# avg / total       0.75      0.72      0.71        60
#
# APR: 0.884
# ROC: 0.847
# Cross-validated estimate
#             accuracy: 0.883 +- 0.067
#            precision: 0.967 +- 0.067
#               recall: 0.800 +- 0.125
#                   f1: 0.868 +- 0.077
#    average_precision: 0.953 +- 0.048
#              roc_auc: 0.933 +- 0.072
# elapsed: 5.1 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 22 #neg: 14
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.81      0.83      0.82        30
#           1       0.83      0.80      0.81        30
#
# avg / total       0.82      0.82      0.82        60
#
# APR: 0.904
# ROC: 0.888
# Cross-validated estimate
#             accuracy: 0.833 +- 0.053
#            precision: 0.960 +- 0.080
#               recall: 0.700 +- 0.067
#                   f1: 0.807 +- 0.058
#    average_precision: 0.928 +- 0.056
#              roc_auc: 0.900 +- 0.096
# elapsed: 5.2 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 36 #neg: 28
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.71      1.00      0.83        30
#           1       1.00      0.60      0.75        30
#
# avg / total       0.86      0.80      0.79        60
#
# APR: 0.936
# ROC: 0.912
# Cross-validated estimate
#             accuracy: 0.867 +- 0.085
#            precision: 0.927 +- 0.090
#               recall: 0.800 +- 0.125
#                   f1: 0.854 +- 0.094
#    average_precision: 0.946 +- 0.048
#              roc_auc: 0.933 +- 0.065
# elapsed: 5.1 sec
# Time elapsed for full repetition: 15.4 sec
# Positive
# graph grammar stats:
# #instances:14   #interfaces: 28   #cores: 99   #core-interface-pairs: 99
# Negative
# graph grammar stats:
# #instances:14   #interfaces: 25   #cores: 65   #core-interface-pairs: 70
# ================================================================================
# repetition: 3/5
# training percentage:0.2
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 14 #neg: 14
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.74      0.83      0.78        30
#           1       0.81      0.70      0.75        30
#
# avg / total       0.77      0.77      0.77        60
#
# APR: 0.905
# ROC: 0.874
# Cross-validated estimate
#             accuracy: 0.800 +- 0.125
#            precision: 0.871 +- 0.176
#               recall: 0.767 +- 0.082
#                   f1: 0.802 +- 0.097
#    average_precision: 0.930 +- 0.058
#              roc_auc: 0.911 +- 0.077
# elapsed: 5.0 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 25 #neg: 16
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.80      0.80      0.80        30
#           1       0.80      0.80      0.80        30
#
# avg / total       0.80      0.80      0.80        60
#
# APR: 0.887
# ROC: 0.840
# Cross-validated estimate
#             accuracy: 0.800 +- 0.041
#            precision: 0.910 +- 0.117
#               recall: 0.700 +- 0.125
#                   f1: 0.774 +- 0.057
#    average_precision: 0.933 +- 0.049
#              roc_auc: 0.906 +- 0.084
# elapsed: 5.0 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 39 #neg: 30
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.71      0.83      0.77        30
#           1       0.80      0.67      0.73        30
#
# avg / total       0.76      0.75      0.75        60
#
# APR: 0.882
# ROC: 0.840
# Cross-validated estimate
#             accuracy: 0.850 +- 0.111
#            precision: 0.900 +- 0.133
#               recall: 0.800 +- 0.125
#                   f1: 0.842 +- 0.111
#    average_precision: 0.898 +- 0.069
#              roc_auc: 0.867 +- 0.095
# elapsed: 5.2 sec
# Time elapsed for full repetition: 15.1 sec
# Positive
# graph grammar stats:
# #instances:14   #interfaces: 28   #cores: 99   #core-interface-pairs: 99
# Negative
# graph grammar stats:
# #instances:14   #interfaces: 25   #cores: 65   #core-interface-pairs: 70
# ================================================================================
# repetition: 4/5
# training percentage:0.2
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 14 #neg: 14
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.77      0.33      0.47        30
#           1       0.57      0.90      0.70        30
#
# avg / total       0.67      0.62      0.58        60
#
# APR: 0.854
# ROC: 0.803
# Cross-validated estimate
#             accuracy: 0.883 +- 0.067
#            precision: 0.967 +- 0.067
#               recall: 0.800 +- 0.125
#                   f1: 0.868 +- 0.077
#    average_precision: 0.942 +- 0.053
#              roc_auc: 0.917 +- 0.084
# elapsed: 5.0 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 25 #neg: 13
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.67      1.00      0.80        30
#           1       1.00      0.50      0.67        30
#
# avg / total       0.83      0.75      0.73        60
#
# APR: 0.854
# ROC: 0.792
# Cross-validated estimate
#             accuracy: 0.833 +- 0.091
#            precision: 0.920 +- 0.098
#               recall: 0.733 +- 0.133
#                   f1: 0.811 +- 0.100
#    average_precision: 0.950 +- 0.064
#              roc_auc: 0.928 +- 0.099
# elapsed: 5.1 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 39 #neg: 27
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.67      0.87      0.75        30
#           1       0.81      0.57      0.67        30
#
# avg / total       0.74      0.72      0.71        60
#
# APR: 0.843
# ROC: 0.784
# Cross-validated estimate
#             accuracy: 0.883 +- 0.041
#            precision: 0.967 +- 0.067
#               recall: 0.800 +- 0.067
#                   f1: 0.872 +- 0.046
#    average_precision: 0.938 +- 0.066
#              roc_auc: 0.917 +- 0.093
# elapsed: 5.1 sec
# Time elapsed for full repetition: 15.2 sec
# Positive
# graph grammar stats:
# #instances:14   #interfaces: 28   #cores: 99   #core-interface-pairs: 99
# Negative
# graph grammar stats:
# #instances:14   #interfaces: 25   #cores: 65   #core-interface-pairs: 70
# ================================================================================
# repetition: 5/5
# training percentage:0.2
# --------------------------------------------------------------------------------
# working on original
# training set sizes: #pos: 14 #neg: 14
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.85      0.73      0.79        30
#           1       0.76      0.87      0.81        30
#
# avg / total       0.81      0.80      0.80        60
#
# APR: 0.918
# ROC: 0.897
# Cross-validated estimate
#             accuracy: 0.883 +- 0.067
#            precision: 0.971 +- 0.057
#               recall: 0.800 +- 0.163
#                   f1: 0.865 +- 0.083
#    average_precision: 0.959 +- 0.034
#              roc_auc: 0.939 +- 0.057
# elapsed: 4.9 sec
# --------------------------------------------------------------------------------
# working on sample
# training set sizes: #pos: 25 #neg: 10
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.70      0.77      0.73        30
#           1       0.74      0.67      0.70        30
#
# avg / total       0.72      0.72      0.72        60
#
# APR: 0.833
# ROC: 0.770
# Cross-validated estimate
#             accuracy: 0.867 +- 0.041
#            precision: 0.933 +- 0.082
#               recall: 0.800 +- 0.067
#                   f1: 0.857 +- 0.044
#    average_precision: 0.946 +- 0.052
#              roc_auc: 0.922 +- 0.081
# elapsed: 5.0 sec
# --------------------------------------------------------------------------------
# working on original+sample
# training set sizes: #pos: 39 #neg: 24
# Test set
# Instances: 60 ; Features: 1048577 with an avg of 1541 features per instance
# --------------------------------------------------------------------------------
# Test Estimate
#              precision    recall  f1-score   support
#
#          -1       0.72      0.97      0.83        30
#           1       0.95      0.63      0.76        30
#
# avg / total       0.84      0.80      0.79        60
#
# APR: 0.944
# ROC: 0.930
# Cross-validated estimate
#             accuracy: 0.817 +- 0.097
#            precision: 0.921 +- 0.102
#               recall: 0.700 +- 0.194
#                   f1: 0.780 +- 0.129
#    average_precision: 0.926 +- 0.047
#              roc_auc: 0.917 +- 0.063
# elapsed: 5.0 sec
# Time elapsed for full repetition: 15.0 sec
# Time elapsed: 0:39:53.737398
